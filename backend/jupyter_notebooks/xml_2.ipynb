# %%
import csv

file_path = "../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"

unique_show_ids = set()
unique_rss_links = set()

with open(file_path, encoding="utf-8") as f:
    reader = csv.DictReader(f, delimiter="\t")
    for row in reader:
        show_id = row["show_uri"].split(":")[-1]
        rss_link = row["rss_link"].strip()
        if rss_link:  # avoid empty ones
            unique_show_ids.add(show_id)
            unique_rss_links.add(rss_link)

print("Unique show IDs:", len(unique_show_ids))
print("Unique RSS links:", len(unique_rss_links))

if len(unique_show_ids) == len(unique_rss_links):
    print("✅ Each show has one unique RSS link.")
else:
    print("⚠️ Mismatch: Some shows share the same RSS link or are missing one.")
# Out:
# Unique show IDs: 18376
# Unique RSS links: 18376
# ✅ Each show has one unique RSS link.

# %%
import feedparser
import pandas as pd

# Function to parse RSS feed and return a pandas DataFrame
def parse_rss_feed(rss_url):
    feed = feedparser.parse(rss_url)

    # Extract show-level data
    show_title = feed.feed.get("title", "")
    show_description = feed.feed.get("description", "")
    show_link = feed.feed.get("link", "")
    show_language = feed.feed.get("language", "")
    show_author = feed.feed.get("author", "")
    show_image = ""
    if "itunes_image" in feed.feed:
        show_image = feed.feed["itunes_image"].get("href", "")
    elif "image" in feed.feed and "href" in feed.feed["image"]:
        show_image = feed.feed["image"]["href"]

    # Extract episodes
    episodes = []
    for entry in feed.entries:
        episode = {
            "show_title": show_title,
            "show_description": show_description,
            "show_link": show_link,
            "show_language": show_language,
            "show_author": show_author,
            "show_image": show_image,
            "episode_title": entry.get("title", ""),
            "episode_description": entry.get("description", ""),
            "episode_link": entry.get("link", ""),
            "episode_guid": entry.get("guid", ""),
            "episode_pubDate": entry.get("published", ""),
            "episode_audio": entry.enclosures[0]["href"] if entry.enclosures else "",
            "episode_duration": entry.get("itunes_duration", ""),
            "episode_summary": entry.get("itunes_summary", ""),
            "episode_image": entry.get("itunes_image", {}).get("href", show_image),
            "episode_explicit": entry.get("itunes_explicit", ""),
            "episode_season": entry.get("itunes_season", ""),
            "episode_number": entry.get("itunes_episode", ""),
            "episode_type": entry.get("itunes_episodeType", "")
        }
        episodes.append(episode)

    df = pd.DataFrame(episodes)
    return df

# Example usage for a Jupyter Notebook
# Replace the URL below with your RSS feed link
rss_url = "https://anchor.fm/s/dfc3598/podcast/rss"
df = parse_rss_feed(rss_url)

# Display the DataFrame
df
# Out:
#                show_title                                   show_description  \
# 0   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 1   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 2   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 3   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 4   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 5   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 6   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 7   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 8   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 9   The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 10  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 11  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 12  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 13  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 14  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 15  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 16  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 17  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 18  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 19  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 20  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 21  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 22  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 23  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 24  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 25  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 26  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 27  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 28  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 29  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 30  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 31  The Christmas Episode  Join Hunter and Brent each week while we tackl...
# 32  The Christmas Episode  Join Hunter and Brent each week while we tackl...
#
#                                             show_link show_language  \
# 0   https://podcasters.spotify.com/pod/show/the-ch...            en
# 1   https://podcasters.spotify.com/pod/show/the-ch...            en
# 2   https://podcasters.spotify.com/pod/show/the-ch...            en
# 3   https://podcasters.spotify.com/pod/show/the-ch...            en
# 4   https://podcasters.spotify.com/pod/show/the-ch...            en
# 5   https://podcasters.spotify.com/pod/show/the-ch...            en
# 6   https://podcasters.spotify.com/pod/show/the-ch...            en
# 7   https://podcasters.spotify.com/pod/show/the-ch...            en
# 8   https://podcasters.spotify.com/pod/show/the-ch...            en
# 9   https://podcasters.spotify.com/pod/show/the-ch...            en
# 10  https://podcasters.spotify.com/pod/show/the-ch...            en
# 11  https://podcasters.spotify.com/pod/show/the-ch...            en
# 12  https://podcasters.spotify.com/pod/show/the-ch...            en
# 13  https://podcasters.spotify.com/pod/show/the-ch...            en
# 14  https://podcasters.spotify.com/pod/show/the-ch...            en
# 15  https://podcasters.spotify.com/pod/show/the-ch...            en
# 16  https://podcasters.spotify.com/pod/show/the-ch...            en
# 17  https://podcasters.spotify.com/pod/show/the-ch...            en
# 18  https://podcasters.spotify.com/pod/show/the-ch...            en
# 19  https://podcasters.spotify.com/pod/show/the-ch...            en
# 20  https://podcasters.spotify.com/pod/show/the-ch...            en
# 21  https://podcasters.spotify.com/pod/show/the-ch...            en
# 22  https://podcasters.spotify.com/pod/show/the-ch...            en
# 23  https://podcasters.spotify.com/pod/show/the-ch...            en
# 24  https://podcasters.spotify.com/pod/show/the-ch...            en
# 25  https://podcasters.spotify.com/pod/show/the-ch...            en
# 26  https://podcasters.spotify.com/pod/show/the-ch...            en
# 27  https://podcasters.spotify.com/pod/show/the-ch...            en
# 28  https://podcasters.spotify.com/pod/show/the-ch...            en
# 29  https://podcasters.spotify.com/pod/show/the-ch...            en
# 30  https://podcasters.spotify.com/pod/show/the-ch...            en
# 31  https://podcasters.spotify.com/pod/show/the-ch...            en
# 32  https://podcasters.spotify.com/pod/show/the-ch...            en
#
#        show_author                                         show_image  \
# 0   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 1   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 2   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 3   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 4   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 5   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 6   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 7   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 8   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 9   Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 10  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 11  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 12  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 13  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 14  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 15  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 16  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 17  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 18  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 19  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 20  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 21  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 22  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 23  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 24  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 25  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 26  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 27  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 28  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 29  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 30  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 31  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 32  Hunter Babcock  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
#
#                                         episode_title  \
# 0                       I Love Lucy Christmas Special
# 1                                     In Excelsis Deo
# 2                     Guess Who's Coming to Christmas
# 3                                  Eddie Murphy/Lizzo
# 4                                   Express Christmas
# 5                                    The Draft Dodger
# 6                       Mr. Monk and the Secret Santa
# 7                     The Christmas Christmas Episode
# 8                              Here Comes Santa Claus
# 9                             Here Comes Aaron Carter
# 10                      The Christmas (Music) Episode
# 11       A Very Special Family Guy Freakin' Christmas
# 12                                     Happy Chanukah
# 13                  I'll Be Home for Christmas (E.R.)
# 14  The TCE Archives - 'Twas the Blight Before Chr...
# 15                                          Midsommar
# 16                 The One With The Halloween Episode
# 17                        Halloween on Spooner Street
# 18                               Halloween (New Girl)
# 19                          Fairy Tales Can Come True
# 20                          The Best Chrismukkah Ever
# 21                 It's the End of Jake As We Know It
# 13  https://anchor.fm/s/dfc3598/podcast/play/84292...         00:34:59
# 14  https://anchor.fm/s/dfc3598/podcast/play/82875...         00:33:29
# 15  https://anchor.fm/s/dfc3598/podcast/play/78186...         00:31:45
# 16  https://anchor.fm/s/dfc3598/podcast/play/75253...         00:36:26
# 17  https://anchor.fm/s/dfc3598/podcast/play/71560...         00:36:21
# 18  https://anchor.fm/s/dfc3598/podcast/play/57711...         00:33:00
# 19  https://anchor.fm/s/dfc3598/podcast/play/50431...         00:35:08
# 20  https://anchor.fm/s/dfc3598/podcast/play/48351...         00:33:51
# 21  https://anchor.fm/s/dfc3598/podcast/play/46897...         00:31:27
# 22  https://anchor.fm/s/dfc3598/podcast/play/46042...         00:30:02
# 23  https://anchor.fm/s/dfc3598/podcast/play/44876...         00:32:53
# 24  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:41:02
# 25  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:30:26
# 26  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:33:22
# 27  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:35:03
# 28  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:32:48
# 29  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:34:24
# 30  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:31:29
# 31  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:33:40
# 32  https://anchor.fm/s/dfc3598/podcast/play/44870...         00:33:22
#
#    episode_summary                                      episode_image  \
# 0                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 1                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 2                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 3                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 4                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 5                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 6                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 7                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 8                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 9                   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 10                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 11                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 12                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 13                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 14                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 15                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 16                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 17                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 18                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 19                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 20                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 21                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 22                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 23                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 24                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 25                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 26                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 27                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 28                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 29                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 30                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 31                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 32                  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
#
#    episode_explicit episode_season episode_number episode_type
# 0              None              2             24
# 1              None              2             23
# 2              None              2             22
# 3              None              2             21
# 4              None              2             20
# 5              None              2             19
# 6              None              2             18
# 7              None              2             17
# 8              None              2             16
# 9              None              2             15
# 10             None              2             14
# 11             None              2             13
# 12             None              2             12
# 13             None              2             11
# 14             None              2             10
# 15             None              2              9
# 16             None              2              8
# 17             None              2              7
# 18             None              2              6
# 19             None              2              5
# 20             None              2              4
# 21             None              2              4
# 22             None              2              3
# 23             None              2              2
# 24             None
# 25             None
# 26             None
# 27             None
# 28             None
# 29             None
# 30             None
# 31             None
# 32             None

# %%
import pandas as pd
import feedparser

# === Settings ===
metadata_path = "../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"
rss_url = "https://anchor.fm/s/dfc3598/podcast/rss"

# === Load Metadata ===
metadata = pd.read_csv(metadata_path, delimiter="\t", encoding="utf-8")
metadata["show_id"] = metadata["show_uri"].apply(lambda x: x.split(":")[-1])
metadata["episode_id"] = metadata["episode_uri"].apply(lambda x: x.split(":")[-1])
metadata["rss_link"] = metadata["rss_link"].astype(str).str.strip()

# Keep only relevant columns
metadata = metadata[[
    "episode_name", "episode_id", "show_name", "show_id", "rss_link"
]]

# === Filter only the show for the given RSS ===
filtered_metadata = metadata[metadata["rss_link"] == rss_url].copy()

# === Parse the RSS Feed ===
feed = feedparser.parse(rss_url)

# Build a dictionary: {guid: entry}
rss_entries = {}
for entry in feed.entries:
    guid = entry.get("guid") or entry.get("id") or entry.get("link")
    if guid:
        rss_entries[guid] = entry

# Get show-level image
show_image = ""
if "itunes_image" in feed.feed:
    show_image = feed.feed["itunes_image"].get("href", "")
elif "image" in feed.feed and "href" in feed.feed["image"]:
    show_image = feed.feed["image"]["href"]

# Prepare final fields
filtered_metadata["image_show"] = show_image
filtered_metadata["image_episode"] = ""
filtered_metadata["audio_url"] = ""

for idx, row in filtered_metadata.iterrows():
    metadata_title = row["episode_name"].strip().lower()  # Normalize metadata title
    matched_entry = None

    # Log matching process
    for guid, entry in rss_entries.items():
        rss_title = entry.get("title", "").strip().lower()  # Normalize RSS title
        #print(f"Checking metadata title: {metadata_title} against RSS title: {rss_title}")
        if metadata_title == rss_title:  # Match by title
            matched_entry = entry
            break

    if matched_entry:
        # Check for audio enclosure
        if matched_entry.enclosures:
            audio_url = matched_entry.enclosures[0].get("href", "")
            filtered_metadata.at[idx, "audio_url"] = audio_url
            print(f"Matched! Metadata title: {metadata_title}, RSS title: {rss_title}, Audio URL: {audio_url}")
        else:
            print(f"⚠️ No audio enclosure for metadata title: {metadata_title}, RSS title: {rss_title}")

        # Set episode image
        filtered_metadata.at[idx, "image_episode"] = matched_entry.get("itunes_image", {}).get("href", show_image)
    else:
        print(f"⚠️ No match found for metadata title: {metadata_title}")

# === Save to CSV or show in notebook ===
output_path = "final_podcast_table.csv"
filtered_metadata = filtered_metadata[[
    "episode_name", "episode_id", "show_name", "show_id",
    "image_show", "image_episode", "audio_url"
]]
#filtered_metadata.to_csv(output_path, index=False)
#print(f"Saved final table to {output_path}")
filtered_metadata
# Out:
# Matched! Metadata title: the christmas (music) episode, RSS title: the christmas (music) episode, Audio URL: https://anchor.fm/s/dfc3598/podcast/play/8805681/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fproduction%2F2019-11-4%2F36606655-44100-2-4c13b6d408342.mp3
# Matched! Metadata title: a very special family guy freakin' christmas, RSS title: a very special family guy freakin' christmas, Audio URL: https://anchor.fm/s/dfc3598/podcast/play/8689403/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fproduction%2F2019-10-27%2F35876883-44100-2-5f1cce13bd017.mp3
# Matched! Metadata title: i'll be home for christmas (e.r.), RSS title: i'll be home for christmas (e.r.), Audio URL: https://anchor.fm/s/dfc3598/podcast/play/8429237/https%3A%2F%2Fd3ctxlq1ktw2nl.cloudfront.net%2Fproduction%2F2019-10-13%2F34053917-44100-2-3151fbc0c0298.mp3
#                                        episode_name              episode_id  \
# 13242                 The Christmas (Music) Episode  0yVedZUm6lNBI2xBJsZigK
# 25725  A Very Special Family Guy Freakin' Christmas  1tb1d5MUQTHN4dCYS5BHbS
# 32709             I'll Be Home for Christmas (E.R.)  2OtcivUOB008EV1RKuWxJ9
#
#                    show_name                 show_id  \
# 13242  The Christmas Episode  5zn6fKhiv7cjHnkaVKptCj
# 25725  The Christmas Episode  5zn6fKhiv7cjHnkaVKptCj
# 32709  The Christmas Episode  5zn6fKhiv7cjHnkaVKptCj
#
#                                               image_show  \
# 13242  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 25725  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 32709  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
#
#                                            image_episode  \
# 13242  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 25725  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 32709  https://d3t3ozftmdmh3i.cloudfront.net/staging/...
#
#                                                audio_url
# 13242  https://anchor.fm/s/dfc3598/podcast/play/88056...
# 25725  https://anchor.fm/s/dfc3598/podcast/play/86894...
# 32709  https://anchor.fm/s/dfc3598/podcast/play/84292...

# %%
import feedparser

# RSS URL
rss_url = "https://anchor.fm/s/dfc3598/podcast/rss"

# Parse feed
feed = feedparser.parse(rss_url)

# Check each episode
missing_audio = []

for entry in feed.entries:
    if not entry.enclosures:
        missing_audio.append(entry.get("title", "Untitled Episode"))

if missing_audio:
    print(f"⚠️ Episodes without audio ({len(missing_audio)}):")
    for title in missing_audio:
        print(f"- {title}")
else:
    print(f"✅ All {len(feed.entries)} episodes have audio enclosures.")
# Out:
# ✅ All 33 episodes have audio enclosures.

# %%
import pandas as pd
import feedparser

# === Settings ===
metadata_path = "../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"

# === Load Metadata ===
metadata = pd.read_csv(metadata_path, delimiter="\t", encoding="utf-8")
metadata["show_id"] = metadata["show_uri"].apply(lambda x: x.split(":")[-1])
metadata["episode_id"] = metadata["episode_uri"].apply(lambda x: x.split(":")[-1])
metadata["rss_link"] = metadata["rss_link"].astype(str).str.strip()

# Keep only relevant columns
metadata = metadata[[
    "episode_name", "episode_id", "show_name", "show_id", "rss_link"
]]

# === Get the first 3 unique RSS links ===
unique_rss_links = metadata["rss_link"].dropna().unique()[:3]

# === Initialize lists and counters ===
episodes_with_audio = []
unmatched_count = 0

# === Process each RSS link ===
for rss_url in unique_rss_links:
    print(f"Processing RSS feed: {rss_url}")

    # === Filter only the show for the given RSS ===
    filtered_metadata = metadata[metadata["rss_link"] == rss_url].copy()

    # === Parse the RSS Feed ===
    feed = feedparser.parse(rss_url)

    # Build a dictionary: {guid: entry}
    rss_entries = {}
    for entry in feed.entries:
        guid = entry.get("guid") or entry.get("id") or entry.get("link")
        if guid:
            rss_entries[guid] = entry

    # Get show-level image
    show_image = ""
    if "itunes_image" in feed.feed:
        show_image = feed.feed["itunes_image"].get("href", "")
    elif "image" in feed.feed and "href" in feed.feed["image"]:
        show_image = feed.feed["image"]["href"]

    # Prepare final fields
    filtered_metadata["image_show"] = show_image
    filtered_metadata["image_episode"] = ""
    filtered_metadata["audio_url"] = ""

    for idx, row in filtered_metadata.iterrows():
        metadata_title = row["episode_name"].strip().lower()  # Normalize metadata title
        matched_entry = None

        # Log matching process
        for guid, entry in rss_entries.items():
            rss_title = entry.get("title", "").strip().lower()  # Normalize RSS title
            if metadata_title == rss_title:  # Match by title
                matched_entry = entry
                break

        if matched_entry:
            # Check for audio enclosure
            if matched_entry.enclosures:
                audio_url = matched_entry.enclosures[0].get("href", "")
                filtered_metadata.at[idx, "audio_url"] = audio_url
                filtered_metadata.at[idx, "image_episode"] = matched_entry.get("itunes_image", {}).get("href", show_image)
                episodes_with_audio.append(filtered_metadata.loc[idx])
                #print(f"Matched! Metadata title: {metadata_title}, RSS title: {rss_title}, Audio URL: {audio_url}")
            else:
                unmatched_count += 1
                print(f"⚠️ No audio enclosure for metadata title: {metadata_title}, RSS title: {rss_title}")
        else:
            unmatched_count += 1
            #print(f"⚠️ No match found for metadata title: {metadata_title}")

# === Convert results to DataFrame ===
df_with_audio = pd.DataFrame(episodes_with_audio)

# === Ensure total entries match ===
total_checked = len(df_with_audio) + unmatched_count
print(f"Total entries checked: {total_checked}")
print(f"Entries with audio: {len(df_with_audio)}")
print(f"Unmatched entries: {unmatched_count}")

# Display the DataFrame
#print("Episodes with audio:")
display(df_with_audio)
# Out:
# Processing RSS feed: https://anchor.fm/s/11b84b68/podcast/rss
# Processing RSS feed: https://anchor.fm/s/b07181c/podcast/rss
# Processing RSS feed: https://anchor.fm/s/81a072c/podcast/rss
# Total entries checked: 263
# Entries with audio: 15
# Unmatched entries: 248
#                                              episode_name  \
# 0                                 1: It’s Christmas Time!
# 11957                             2: Tan Hands Save Lives
# 46132                         6: #BYOD (with Liz Pickles)
# 29274   The Bodies In The Bathtubs - January 11 2020 -...
# 31887     Welcome To December - Teasers, Promos and more!
# 33707   Bind Torture and Kill B.T.K. - January 15 2020...
# 48243   Murder Over A Locked Safe - January 28 2020 - ...
# 54166   Welcome to October 2019! Updates, Information ...
# 63415   Worst Serial Killer in Slovakian History - Dec...
# 81917   Intro to January with True Crime Finland and T...
# 91279       Christmas Shopping Tragedy - December 19 2019
# 99079   The Controversy of The Death Penalty - January...
# 104773  The Werewolf of Wysteria Albert Fish - January...
# 17867   Ep.73 - Coaching While Playing & Why it Develo...
# 92612   Ep.72 - Live w/ Womens World Cup Star, Jamaica...
#
#                     episode_id  \
# 0       000A9sRBYdVh66csG2qEdj
# 11957   0sTNg31EACSHfZlt41RHmS
# 46132   3Ny7dKZ1QHZwadslXJ8Umf
# 29274   29YonFNXG3zgpovmN5jsPg
# 31887   2LFdc0F51vDtF3eYB0PV4t
# 33707   2TN8ceYiYt3s4rKAdLrjtq
# 48243   3XGKTbzFsWXhEhhhFuTVPQ
# 54166   3yJGK1sfUNhk96hHDoaG19
# 63415   4fMRDkraf5vDFj3nUjg40m
# 81917   62Qh8UhqU9Pb5vhwpPm8ZX
# 91279   6k730eNNpeL9iUqUrQaM28
# 99079   7Jrkc09gnXex1gyiyVCyVd
# 104773  7xJ7qsg6j84EFU70SrqdbJ
# 17867   1JegHlJfLoD8zxW9j3054u
# 92612   6qEKXa3eOECx4H2jCEy9df
#
#                                                 show_name  \
# 0                                    Kream in your Koffee
# 11957                                Kream in your Koffee
# 46132                                Kream in your Koffee
# 48243   https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 54166   https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 63415   https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 81917   https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 91279   https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 99079   https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 104773  https://chrt.fm/track/4EB79A/pscrb.fm/rss/p/tr...
# 17867   https://pscrb.fm/rss/p/mgln.ai/e/1385/clrtpod....
# 92612   https://pscrb.fm/rss/p/mgln.ai/e/1385/clrtpod....

# %%
# Count the number of unique RSS links in the metadata
unique_rss_links_count = metadata["rss_link"].nunique()
print(f"Number of unique RSS links in the metadata: {unique_rss_links_count}")
# Out:
# Number of unique RSS links in the metadata: 18376

# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lpa/SE_podcast_search/venv/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lpa/SE_podcast_search/venv/lib/python3.12/site-packages (from requests) (2025.1.31)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Installing collected packages: idna, charset-normalizer, requests
# Successfully installed charset-normalizer-3.4.1 idna-3.10 requests-2.32.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import feedparser
import time
import requests

# === Settings ===
metadata_path = "../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"

# === Load Metadata ===
metadata = pd.read_csv(metadata_path, delimiter="\t", encoding="utf-8")
metadata["show_id"] = metadata["show_uri"].apply(lambda x: x.split(":")[-1])
metadata["episode_id"] = metadata["episode_uri"].apply(lambda x: x.split(":")[-1])
metadata["rss_link"] = metadata["rss_link"].astype(str).str.strip()

# Keep only relevant columns
metadata = metadata[[
    "episode_name", "episode_id", "show_name", "show_id", "rss_link"
]]

# === Get the first 500 unique RSS links ===
unique_rss_links = metadata["rss_link"].dropna().unique()[:500]

# === Initialize lists and counters ===
episodes_with_audio = []
unmatched_count = 0

# === Start timing ===
start_time = time.time()

# === Process each RSS link ===
for rss_url, index in unique_rss_links:
    print(f"{index}: Processing RSS feed: {rss_url}")

    # Check if the URL is accessible within 5 seconds
    try:
        response = requests.get(rss_url, timeout=5)
        if response.status_code != 200:
            print(f"⚠️ Unable to access RSS feed: {rss_url} (Status code: {response.status_code})")
            continue
    except requests.exceptions.RequestException as e:
        print(f"⚠️ Timeout or error accessing RSS feed: {rss_url} ({e})")
        continue

    # === Filter only the show for the given RSS ===
    filtered_metadata = metadata[metadata["rss_link"] == rss_url].copy()

    # === Parse the RSS Feed ===
    feed = feedparser.parse(rss_url)

    # Build a dictionary: {guid: entry}
    rss_entries = {}
    for entry in feed.entries:
        guid = entry.get("guid") or entry.get("id") or entry.get("link")
        if guid:
            rss_entries[guid] = entry

    # Get show-level image
    show_image = ""
    if "itunes_image" in feed.feed:
        show_image = feed.feed["itunes_image"].get("href", "")
    elif "image" in feed.feed and "href" in feed.feed["image"]:
        show_image = feed.feed["image"]["href"]

    # Prepare final fields
    filtered_metadata["image_show"] = show_image
    filtered_metadata["image_episode"] = ""
    filtered_metadata["audio_url"] = ""

    for idx, row in filtered_metadata.iterrows():
        metadata_title = row["episode_name"].strip().lower()  # Normalize metadata title
        matched_entry = None

        # Log matching process
        for guid, entry in rss_entries.items():
            rss_title = entry.get("title", "").strip().lower()  # Normalize RSS title
            if metadata_title == rss_title:  # Match by title
                matched_entry = entry
                break

        if matched_entry:
            # Check for audio enclosure
            if matched_entry.enclosures:
                audio_url = matched_entry.enclosures[0].get("href", "")
                filtered_metadata.at[idx, "audio_url"] = audio_url
                filtered_metadata.at[idx, "image_episode"] = matched_entry.get("itunes_image", {}).get("href", show_image)
                episodes_with_audio.append(filtered_metadata.loc[idx])
                #print(f"Matched! Metadata title: {metadata_title}, RSS title: {rss_title}, Audio URL: {audio_url}")
            else:
                unmatched_count += 1
                print(f"⚠️ No audio enclosure for metadata title: {metadata_title}, RSS title: {rss_title}")
        else:
            unmatched_count += 1
            #print(f"⚠️ No match found for metadata title: {metadata_title}")

# === End timing ===
end_time = time.time()
elapsed_time = end_time - start_time

# === Convert results to DataFrame ===
df_with_audio = pd.DataFrame(episodes_with_audio)

# === Ensure total entries match ===
total_checked = len(df_with_audio) + unmatched_count
print(f"Total entries checked: {total_checked}")
print(f"Entries with audio: {len(df_with_audio)}")
print(f"Unmatched entries: {unmatched_count}")
print(f"Time taken to process 500 RSS links: {elapsed_time:.2f} seconds")

# Display the DataFrame
print("Episodes with audio:")
display(df_with_audio)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import feedparser
#       3 import time
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import feedparser
import time
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed

# === Settings ===
metadata_path = "../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"
MAX_WORKERS = 10  # Number of threads for parallel processing

# === Load Metadata ===
metadata = pd.read_csv(metadata_path, delimiter="\t", encoding="utf-8")
metadata["show_id"] = metadata["show_uri"].apply(lambda x: x.split(":")[-1])
metadata["episode_id"] = metadata["episode_uri"].apply(lambda x: x.split(":")[-1])
metadata["rss_link"] = metadata["rss_link"].astype(str).str.strip()

# Keep only relevant columns
metadata = metadata[[
    "episode_name", "episode_id", "show_name", "show_id", "rss_link"
]]

# === Get the first 500 unique RSS links ===
unique_rss_links = metadata["rss_link"].dropna().unique()[:500]

# === Initialize lists and counters ===
episodes_with_audio = []
unmatched_count = 0

# === Function to process a single RSS link ===
def process_rss_link(rss_url):
    global unmatched_count
    try:
        # Check if the URL is accessible within 5 seconds
        response = requests.get(rss_url, timeout=5)
        if response.status_code != 200:
            print(f"⚠️ Unable to access RSS feed: {rss_url} (Status code: {response.status_code})")
            return []

        # Parse the RSS Feed
        feed = feedparser.parse(rss_url)

        # Build a dictionary: {guid: entry}
        rss_entries = {}
        for entry in feed.entries:
            guid = entry.get("guid") or entry.get("id") or entry.get("link")
            if guid:
                rss_entries[guid] = entry

        # Get show-level image
        show_image = ""
        if "itunes_image" in feed.feed:
            show_image = feed.feed["itunes_image"].get("href", "")
        elif "image" in feed.feed and "href" in feed.feed["image"]:
            show_image = feed.feed["image"]["href"]

        # Filter metadata for the current RSS link
        filtered_metadata = metadata[metadata["rss_link"] == rss_url].copy()
        filtered_metadata["image_show"] = show_image
        filtered_metadata["image_episode"] = ""
        filtered_metadata["audio_url"] = ""

        matched_episodes = []
        for idx, row in filtered_metadata.iterrows():
            metadata_title = row["episode_name"].strip().lower()  # Normalize metadata title
            matched_entry = None

            # Match metadata title with RSS entry title
            for guid, entry in rss_entries.items():
                rss_title = entry.get("title", "").strip().lower()  # Normalize RSS title
                if metadata_title == rss_title:
                    matched_entry = entry
                    break

            if matched_entry:
                # Check for audio enclosure
                if matched_entry.enclosures:
                    audio_url = matched_entry.enclosures[0].get("href", "")
                    filtered_metadata.at[idx, "audio_url"] = audio_url
                    filtered_metadata.at[idx, "image_episode"] = matched_entry.get("itunes_image", {}).get("href", show_image)
                    matched_episodes.append(filtered_metadata.loc[idx])
                else:
                    unmatched_count += 1
            else:
                unmatched_count += 1

        return matched_episodes

    except requests.exceptions.RequestException as e:
        #print(f"⚠️ Timeout or error accessing RSS feed: {rss_url} ({e})")
        return []

# === Start timing ===
start_time = time.time()

# === Process RSS links in parallel ===
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(process_rss_link, rss_url): rss_url for rss_url in unique_rss_links}
    for future in as_completed(futures):
        rss_url = futures[future]
        try:
            episodes_with_audio.extend(future.result())
        except Exception as e:
            #print(f"⚠️ Error processing RSS feed: {rss_url} ({e})")

# === End timing ===
end_time = time.time()
elapsed_time = end_time - start_time

# === Convert results to DataFrame ===
df_with_audio = pd.DataFrame(episodes_with_audio)

# === Ensure total entries match ===
total_checked = len(df_with_audio) + unmatched_count
print(f"Total entries checked: {total_checked}")
print(f"Entries with audio: {len(df_with_audio)}")
print(f"Unmatched entries: {unmatched_count}")
print(f"Time taken to process 500 RSS links: {elapsed_time:.2f} seconds")

# Display the DataFrame
print("Episodes with audio:")
display(df_with_audio)
# Out:
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/fa62700/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/11a7abf0/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/e2aaf40/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/4b4f394/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/70bc028/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/d8cf584/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/e59de8c/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/129266f4/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/87afb18/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/fc369a0/podcast/rss (Status code: 404)
# ⚠️ Timeout or error accessing RSS feed: https://podcast.rss.com/elevate/feed.xml (HTTPSConnectionPool(host='podcast.rss.com', port=443): Max retries exceeded with url: /elevate/feed.xml (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fd867dac3b0>, 'Connection to podcast.rss.com timed out. (connect timeout=5)')))
# ⚠️ Timeout or error accessing RSS feed: https://anchor.fm/s/c3b6a94/podcast/rss (HTTPSConnectionPool(host='feeds.castfire.com', port=443): Max retries exceeded with url: /townsquare-media/elpaso___klaqfm___what_the_buzz___apple_podcasts (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7fd86bddb1a0>: Failed to resolve 'feeds.castfire.com' ([Errno -2] Name or service not known)")))
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/2d09330/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/cd063b0/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/aa10cac/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/c01cbcc/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/ac75a24/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/5971378/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/b2da798/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/96cbfac/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/ef0c504/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/f619b58/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/d4d4470/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/5875dfc/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/10ec4d24/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/f067944/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/c390998/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/c65daa4/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/cc30314/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/113d8108/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/bbd6c48/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/b0ae1a4/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/b7590f8/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/d29f7b8/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/73efc90/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/6ba6728/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/c3679bc/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/81492b0/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/a6879dc/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/884fd34/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/fa317cc/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/896ffc0/podcast/rss (Status code: 404)
# ⚠️ Unable to access RSS feed: https://www.spreaker.com/show/957147/episodes/feed-spotify (Status code: 404)
# ⚠️ Unable to access RSS feed: https://anchor.fm/s/6ef2580/podcast/rss (Status code: 404)
# Total entries checked: 21195
# Entries with audio: 18405
# Unmatched entries: 2790
# Time taken to process 500 RSS links: 179.36 seconds
# Episodes with audio:
#                                              episode_name  \
# 9                                   Talia and me part 2!
# 5381                                   Me and my big sis
# 30697                        Dealing with Disappointment
# 31671                                             Q and A
# 34487   Donna Simantov reminds you to stay positive an...
# ...                                                   ...
# 104526  Trauma⎜Radial Head Fractures (ft. Dr. Joaquin ...
# 104596  Question Session⎪Femoroacetabular Impingement ...
# 105003                                  Hand⎪Replantation
# 105180  Shoulder & Elbow⎪Osteochondritis Dissecans of ...
# 105345  Basic Science | Clinical Trial Design & Levels...
#
#                     episode_id                 show_name  \
# 9       003EmVD7eAmRTBSwHXqi1W            The Good Sign
# 5381    0OHm5UCels4t8Mk7KYwzC5            The Good Sign
# 30697   2G3wbzYhNY9Yinr7KuNumD            The Good Sign
# 31671   2KLGk8qQVQiCz8JApKcikY            The Good Sign
# 34487   2WpkZSA6TqXd4qLZpDQK4O            The Good Sign
# ...                        ...                       ...
# 104526  7w4m61Gx0FNc18NQzTNSc9  The Orthobullets Podcast
# 104596  7wPBa4ygniHYtBZTm5vQgD  The Orthobullets Podcast
# 105003  7yOahSvk2aqSfXfidVuXUT  The Orthobullets Podcast
# 105180  7zFqPzptxpgkt9eqIBGJKd  The Orthobullets Podcast
# 105345  7zx1wwkDGPFy4Cf8zHuVss  The Orthobullets Podcast
#
#                        show_id                                 rss_link  \
# 9       1dyTrS3vDtpClrURfKdo3q  https://anchor.fm/s/fef17a8/podcast/rss
# 5381    1dyTrS3vDtpClrURfKdo3q  https://anchor.fm/s/fef17a8/podcast/rss
# 30697   1dyTrS3vDtpClrURfKdo3q  https://anchor.fm/s/fef17a8/podcast/rss
# 31671   1dyTrS3vDtpClrURfKdo3q  https://anchor.fm/s/fef17a8/podcast/rss
# 34487   1dyTrS3vDtpClrURfKdo3q  https://anchor.fm/s/fef17a8/podcast/rss
# ...                        ...                                      ...
# 104526  0I22C9iyvVT3M6DEILuD9F  https://anchor.fm/s/415caa8/podcast/rss
# 104596  0I22C9iyvVT3M6DEILuD9F  https://anchor.fm/s/415caa8/podcast/rss
# 105003  0I22C9iyvVT3M6DEILuD9F  https://anchor.fm/s/415caa8/podcast/rss
# 105180  0I22C9iyvVT3M6DEILuD9F  https://anchor.fm/s/415caa8/podcast/rss
# 105345  0I22C9iyvVT3M6DEILuD9F  https://anchor.fm/s/415caa8/podcast/rss
#
#                                                image_show  \
# 9       https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 5381    https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 30697   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 31671   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 34487   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# ...                                                   ...
# 104526  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 104596  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 105003  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 105180  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 105345  https://d3t3ozftmdmh3i.cloudfront.net/producti...
#
#                                             image_episode  \
# 9       https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 5381    https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 30697   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 31671   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# 34487   https://d3t3ozftmdmh3i.cloudfront.net/staging/...
# ...                                                   ...
# 104526  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 104596  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 105003  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 105180  https://d3t3ozftmdmh3i.cloudfront.net/producti...
# 105345  https://d3t3ozftmdmh3i.cloudfront.net/producti...
#
#                                                 audio_url
# 9       https://anchor.fm/s/fef17a8/podcast/play/88990...
# 5381    https://anchor.fm/s/fef17a8/podcast/play/86810...
# 30697   https://anchor.fm/s/fef17a8/podcast/play/85188...
# 31671   https://anchor.fm/s/fef17a8/podcast/play/87655...
# 34487   https://anchor.fm/s/fef17a8/podcast/play/82036...
# ...                                                   ...
# 104526  https://anchor.fm/s/415caa8/podcast/play/26920...
# 104596  https://anchor.fm/s/415caa8/podcast/play/49327...
# 105003  https://anchor.fm/s/415caa8/podcast/play/83981...
# 105180  https://anchor.fm/s/415caa8/podcast/play/40964...
# 105345  https://anchor.fm/s/415caa8/podcast/play/27020...
#
# [18405 rows x 8 columns]

# %%
import pandas as pd
import feedparser
import time
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed

# === Settings ===
metadata_path = "../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"
MAX_WORKERS = 10  # Number of threads for parallel processing

# === Load Metadata ===
metadata = pd.read_csv(metadata_path, delimiter="\t", encoding="utf-8")
metadata["show_id"] = metadata["show_uri"].apply(lambda x: x.split(":")[-1])
metadata["episode_id"] = metadata["episode_uri"].apply(lambda x: x.split(":")[-1])
metadata["rss_link"] = metadata["rss_link"].astype(str).str.strip()

# Keep only relevant columns
metadata = metadata[[
    "episode_name", "episode_id", "show_name", "show_id", "rss_link"
]]

# === Get all unique RSS links ===
unique_rss_links = metadata["rss_link"].dropna().unique()

# === Initialize lists and counters ===
episodes_with_audio = []
unmatched_count = 0

# === Function to process a single RSS link ===
def process_rss_link(rss_url):
    global unmatched_count
    try:
        # Check if the URL is accessible within 5 seconds
        response = requests.get(rss_url, timeout=5)
        if response.status_code != 200:
            #print(f"⚠️ Unable to access RSS feed: {rss_url} (Status code: {response.status_code})")
            return []

        # Parse the RSS Feed
        feed = feedparser.parse(rss_url)

        # Build a dictionary: {guid: entry}
        rss_entries = {}
        for entry in feed.entries:
            guid = entry.get("guid") or entry.get("id") or entry.get("link")
            if guid:
                rss_entries[guid] = entry

        # Get show-level image
        show_image = ""
        if "itunes_image" in feed.feed:
            show_image = feed.feed["itunes_image"].get("href", "")
        elif "image" in feed.feed and "href" in feed.feed["image"]:
            show_image = feed.feed["image"]["href"]

        # Filter metadata for the current RSS link
        filtered_metadata = metadata[metadata["rss_link"] == rss_url].copy()
        filtered_metadata["image_show"] = show_image
        filtered_metadata["image_episode"] = ""
        filtered_metadata["audio_url"] = ""

        matched_episodes = []
        for idx, row in filtered_metadata.iterrows():
            metadata_title = row["episode_name"].strip().lower()  # Normalize metadata title
            matched_entry = None

            # Match metadata title with RSS entry title
            for guid, entry in rss_entries.items():
                rss_title = entry.get("title", "").strip().lower()  # Normalize RSS title
                if metadata_title == rss_title:
                    matched_entry = entry
                    break

            if matched_entry:
                # Check for audio enclosure
                if matched_entry.enclosures:
                    audio_url = matched_entry.enclosures[0].get("href", "")
                    filtered_metadata.at[idx, "audio_url"] = audio_url
                    filtered_metadata.at[idx, "image_episode"] = matched_entry.get("itunes_image", {}).get("href", show_image)
                    matched_episodes.append(filtered_metadata.loc[idx])
                else:
                    unmatched_count += 1
            else:
                unmatched_count += 1

        return matched_episodes

    except requests.exceptions.RequestException as e:
        #print(f"⚠️ Timeout or error accessing RSS feed: {rss_url} ({e})")
        return []

# === Start timing ===
start_time = time.time()

# === Process RSS links in parallel ===
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(process_rss_link, rss_url): rss_url for rss_url in unique_rss_links}
    for future in as_completed(futures):
        rss_url = futures[future]
        try:
            episodes_with_audio.extend(future.result())
        except Exception as e:
            next
            #print(f"⚠️ Error processing RSS feed: {rss_url} ({e})")

# === End timing ===
end_time = time.time()
elapsed_time = end_time - start_time

# === Convert results to DataFrame ===
df_with_audio = pd.DataFrame(episodes_with_audio)

# === Ensure total entries match ===
total_checked = len(df_with_audio) + unmatched_count
print(f"Total entries checked: {total_checked}")
print(f"Entries with audio: {len(df_with_audio)}")
print(f"Unmatched entries: {unmatched_count}")
print(f"Time taken to process all RSS links: {elapsed_time:.2f} seconds")

# Save the DataFrame to a CSV file
output_path = "final_podcast_table_all.csv"
df_with_audio.to_csv(output_path, index=False)
print(f"Saved final table to {output_path}")
# Out:
# Total entries checked: 96709
# Entries with audio: 82480
# Unmatched entries: 14229
# Time taken to process all RSS links: 1181.80 seconds
# Saved final table to final_podcast_table_all.csv

# %%
import pandas as pd
import feedparser
import time
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm 

# === Settings ===
metadata_path = "../../podcasts-no-audio-13GB/metadata/spotify-podcasts-2020/metadata.tsv"
MAX_WORKERS = 10  # Number of threads for parallel processing

# === Load Metadata ===
metadata = pd.read_csv(metadata_path, delimiter="\t", encoding="utf-8")
metadata["show_id"] = metadata["show_uri"].apply(lambda x: x.split(":")[-1])
metadata["episode_id"] = metadata["episode_uri"].apply(lambda x: x.split(":")[-1])
metadata["rss_link"] = metadata["rss_link"].astype(str).str.strip()

                
# Keep only relevant columns
metadata = metadata[[
    "episode_name", "episode_id", "show_name", "show_id", "rss_link", "language", "publisher", "episode_description", "duration"
]]

# === Get all unique RSS links ===
unique_rss_links = metadata["rss_link"].dropna().unique()

# === Initialize lists and counters ===
episodes_with_audio = []
unmatched_count = 0

# === Function to process a single RSS link ===
def process_rss_link(rss_url):
    global unmatched_count
    try:
        # Check if the URL is accessible within 5 seconds
        response = requests.get(rss_url, timeout=5)
        if response.status_code != 200:
            #print(f"⚠️ Unable to access RSS feed: {rss_url} (Status code: {response.status_code})")
            return []

        # Parse the RSS Feed
        feed = feedparser.parse(rss_url)

        # Build a dictionary: {guid: entry}
        rss_entries = {}
        for entry in feed.entries:
            guid = entry.get("guid") or entry.get("id") or entry.get("link")
            if guid:
                rss_entries[guid] = entry

        # Get show-level image
        show_image = ""
        if "itunes_image" in feed.feed:
            show_image = feed.feed["itunes_image"].get("href", "")
        elif "image" in feed.feed and "href" in feed.feed["image"]:
            show_image = feed.feed["image"]["href"]

        # Filter metadata for the current RSS link
        filtered_metadata = metadata[metadata["rss_link"] == rss_url].copy()
        filtered_metadata["image_show"] = show_image
        filtered_metadata["image_episode"] = ""
        filtered_metadata["audio_url"] = ""

        matched_episodes = []
        for idx, row in filtered_metadata.iterrows():
            metadata_title = row["episode_name"].strip().lower()  # Normalize metadata title
            matched_entry = None

            # Match metadata title with RSS entry title
            for guid, entry in rss_entries.items():
                rss_title = entry.get("title", "").strip().lower()  # Normalize RSS title
                if metadata_title == rss_title:
                    matched_entry = entry
                    break

            if matched_entry:
                # Check for audio enclosure
                if matched_entry.enclosures:
                    audio_url = matched_entry.enclosures[0].get("href", "")
                    filtered_metadata.at[idx, "audio_url"] = audio_url
                    filtered_metadata.at[idx, "image_episode"] = matched_entry.get("itunes_image", {}).get("href", show_image)
                    matched_episodes.append(filtered_metadata.loc[idx])
                else:
                    unmatched_count += 1
            else:
                unmatched_count += 1

        return matched_episodes

    except requests.exceptions.RequestException as e:
        #print(f"⚠️ Timeout or error accessing RSS feed: {rss_url} ({e})")
        return []

# === Start timing ===
start_time = time.time()

# === Process RSS links in parallel ===
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(process_rss_link, rss_url): rss_url for rss_url in unique_rss_links}
    for future in tqdm(as_completed(futures), total=len(futures), desc="Processing RSS feeds"):
        rss_url = futures[future]
        try:
            episodes_with_audio.extend(future.result())
        except Exception as e:
            next
            #print(f"⚠️ Error processing RSS feed: {rss_url} ({e})")

# === Add unmatched episodes ===
matched_episode_ids = {episode["episode_id"] for episode in episodes_with_audio}
unmatched_metadata = metadata[~metadata["episode_id"].isin(matched_episode_ids)].copy()
unmatched_metadata["image_show"] = ""
unmatched_metadata["image_episode"] = ""
unmatched_metadata["audio_url"] = ""

# Combine matched and unmatched episodes
df_with_audio = pd.DataFrame(episodes_with_audio)
df_with_audio = pd.concat([df_with_audio, unmatched_metadata], ignore_index=True)

# === End timing ===
end_time = time.time()
elapsed_time = end_time - start_time

# === Ensure total entries match ===
total_checked = len(df_with_audio)
print(f"Total entries checked: {total_checked}")
print(f"Entries with audio: {len(df_with_audio) - len(unmatched_metadata)}")
print(f"Unmatched entries: {len(unmatched_metadata)}")
print(f"Time taken to process all RSS links: {elapsed_time:.2f} seconds")

# Save the DataFrame to a CSV file
output_path = "final_podcast_table_all_with_unmatched.csv"
df_with_audio.to_csv(output_path, index=False)
print(f"Saved final table to {output_path}")
# Out:
# Processing RSS feeds: 100%|██████████| 18376/18376 [20:40<00:00, 14.82it/s]
# Total entries checked: 105360
# Entries with audio: 82436
# Unmatched entries: 22924
# Time taken to process all RSS links: 1241.40 seconds
# Saved final table to final_podcast_table_all_with_unmatched.csv
